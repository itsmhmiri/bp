# %% [markdown]
# <center><h1>
# Chapter 5 — `if` Statements (Python Crash Course)
# یادگیری `if` در پایتون (فصل ۵ کتاب Python Crash Course)
# <h1><center>

# %% [markdown]
# <p style="text-align:center;">محمد مهدی حاجی مبینی</p>

# %% [markdown]
# ## Table of contents / فهرست
# 1. What is a conditional test? / تست شرطی چیست؟
# 2. Checking equality / بررسی برابری (`==`)
# 3. Checking inequality / بررسی نابرابری (`!=`)
# 4. String comparisons + case / مقایسه رشته‌ها + حروف کوچک/بزرگ
# 5. Numerical comparisons / مقایسه‌های عددی
# 6. `and` / `or` / ترکیب شرط‌ها
# 7. `in` and `not in` / وجود داشتن در لیست و نبودن در لیست
# 8. Boolean values / مقادیر بولی
# 9. Simple `if` / `if` ساده
# 10. `if-else` / شرط دو حالته
# 11. `if-elif-else` chain / زنجیره‌ی `if-elif-else`
# 12. Multiple `elif` blocks / چندین `elif`
# 13. Omitting `else` / حذف `else` (ایمن‌تر)
# 14. Testing multiple conditions / تست چند شرط مستقل (چند `if`)
# 15. `if` with lists / استفاده از `if` با لیست‌ها
# 16. Checking for special items / آیتم‌های خاص (مثل حذف anchovies)
# 17. Checking list is not empty / چک کردن خالی نبودن لیست
# 18. Using multiple lists / استفاده از دو لیست (available vs requested)
# 19. Try It Yourself (5‑1 … 5‑11) + Solutions / تمرین‌ها + پاسخ‌ها

# %% [markdown]
# # Introduction - مقدمه

# %% [markdown]
# <p style="text-align:right;">در این فصل یاد میگیرید چگونه از آزمون های شرطی و دستورت ساده شرطی و استفاده آن در لیست ها استفاده کنید</p>

# %% [markdown]
# ### In this chapter you’ll learn to write conditional tests, which allow you to check any condition of interest. You’ll learn to write simple if statements, and you’ll learn how to create a more complex series of if statements to identify when the exact conditions you want are present. You’ll then apply this concept to lists, so you’ll be able to write a for loop that handles most items in a list one way but handles certain items with specific values in a different way.

# %% [markdown]
# # Bonus: `for` Loops (because Chapter 5 uses them)
# <div dir="rtl">
# بخش تکمیلی: حلقه‌ `for` (چون در فصل ۵ زیاد استفاده می‌شود)
# </div>
# In Chapter 5, many `if` examples are used **inside a `for` loop** (like checking each topping or each user).
# So you need to understand `for` to fully understand the chapter.
#
# <div dir="rtl">
# در فصل ۵، خیلی از مثال‌های <code>if</code> داخل حلقه‌ی <code>for</code> هستند (مثلاً بررسی هر تاپینگ یا هر کاربر).
# پس برای اینکه فصل رو کامل یاد بگیری، باید <code>for</code> رو هم بلد باشی.
# </div>
#
# ---
#
# ## 1) What is a `for` loop? / حلقه‌ی `for` چیست؟
#
# A `for` loop repeats a block of code for **each item** in a sequence (like a list).
# <div dir="rtl">
# حلقه‌ی <code>for</code> یک بلوک کد را برای **هر آیتم** در یک دنباله (مثل لیست) تکرار می‌کند.
# </div>
# ### Syntax / ساختار
# ```python
# for item in items:
#     # do something with item
# ```
# <div dir="rtl">
# در هر تکرار، مقدار <code>item</code> یکی از اعضای <code>items</code> می‌شود و کد داخل بلوک اجرا می‌شود.
# </div>

# %% [markdown]
# # Example 1: Loop through a list / مثال ۱: پیمایش لیست

# %% [markdown]
# `.title`
# <div dir="rtl">
# اول هر کلمه رو حرف بزرگ می‌کنه و بقیه حروف رو کوچک میکند
# </div>

# %%
names = ["ali", "sara", "mike"]

for name in names:
    print(f"Hello, {name.title()}!")
# Out:
# Hello, Ali!
# Hello, Sara!
# Hello, Mike!

# %% [markdown]
# ## 2) `for` with `if` (very common) / ترکیب `for` با `if`
#
# You can check a condition for **each** item in the loop.
# <div dir="rtl">
# می‌تونی برای **هر** آیتم داخل حلقه یک شرط چک کنی.
# </div>
# Example: special message for `admin`.
# مثال: پیام ویژه برای `admin`.

# %%
usernames = ["admin", "eric", "sara"]

for username in usernames:
    if username == "admin":
        print("Hello admin, would you like to see a status report?")
    else:
        print(f"Hello {username.title()}, thank you for logging in again.")
# Out:
# Hello admin, would you like to see a status report?
# Hello Eric, thank you for logging in again.
# Hello Sara, thank you for logging in again.

# %% [markdown]
# ## 3) `break` and `continue` (optional but useful)
# ### `break` و `continue` (اختیاری ولی کاربردی)
#
# - `break` stops the loop immediately. / حلقه را همان لحظه قطع می‌کند.
# - `continue` skips to the next iteration. / این دور را رد می‌کند و می‌رود سراغ بعدی.

# %%
numbers = [1, 3, 5, 7, 9]

for n in numbers:
    if n == 7:
        print("Found 7 stopping...")
        break
    print("n =", n)
# Out:
# n = 1
# n = 3
# n = 5
# Found 7 stopping...

# %%
numbers = [1, 2, 3, 4, 5]

for n in numbers:
    if n % 2 == 0:
        continue  # skip evens
    print("odd:", n)
# Out:
# odd: 1
# odd: 3
# odd: 5

# %% [markdown]
# ## 4) Indentation in `for` / تورفتگی در `for`
#
# Just like `if`, Python uses indentation to define the loop block.
# مثل <code>if</code>، در <code>for</code> هم تورفتگی مشخص می‌کند چه کدی داخل حلقه است.
#
# **Common mistake:** forgetting indentation → `IndentationError`.
# اشتباه رایج: تورفتگی اشتباه → خطای <code>IndentationError</code>.

# %%
numbers = [1,2,3,4,5]
for n in numbers:
print(n)
# Out:
#   Cell In[10], line 3
#     print(n)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %% [markdown]
# ## 1) Conditional tests / تست‌های شرطی
#
# A **conditional test** is an expression that becomes `True` or `False`.
# یک **تست شرطی** عبارتیه که نتیجه‌اش `True` یا `False` می‌شه.

# %%
age = 18
print(age == 18)   # True
print(age == 19)   # False

# %% [markdown]
# ## 2) Checking equality (`==`) / بررسی برابری
#
# `==` checks whether two values are equal.
# `==` بررسی می‌کنه آیا دو مقدار برابر هستند یا نه.

# %%
car = 'subaru'
print("Is car == 'subaru'?")
print(car == 'subaru')

print("Is car == 'audi'?")
print(car == 'audi')

# %% [markdown]
# ## 3) Checking inequality (`!=`) / بررسی نابرابری
#
# `!=` means **not equal**.
# `!=` یعنی **برابر نیست**.

# %%
requested_topping = 'mushrooms'

if requested_topping != 'extra cheese':
    print("Hold the cheese!")

# %% [markdown]
# ## 4) String comparisons + case / مقایسه رشته‌ها + حروف کوچک/بزرگ
#
# String comparisons are case-sensitive.
# مقایسه رشته‌ها به بزرگ/کوچک بودن حروف حساس است.

# %% [markdown]
# `.lower`
# همه‌ی حروف یک رشته رو به حروف کوچک تبدیل می‌کنه

# %%
username = "John"
print(username == "john")  # False (case-sensitive)

print(username.lower() == "john")  # True (case-insensitive check)
print(username)  # original unchanged

# %%
car = "Toyota"
print(car == "toyota")  # False
print(car.lower() == "toyota")  # True
print(car)  # original unchanged

# %% [markdown]
# ## 5) Numerical comparisons / مقایسه‌های عددی
#
# You can use `<`, `<=`, `>`, `>=`, `==`, `!=`.
# می‌تونی از `<`، `<=`، `>`، `>=`، `==`، `!=` استفاده کنی.

# %%
age = 19
print(age < 21)
print(age <= 21)
print(age > 21)
print(age >= 21)

# %%
answer = 17
if answer != 42:
    print("That is not the correct answer. Please try again!")

# %% [markdown]
# ## 6) Checking multiple conditions: `and` / `or`
# ### ترکیب شرط‌ها با `and` و `or`
#
# - `and`: both must be True / هر دو باید True باشند
# - `or`: at least one must be True / حداقل یکی True باشد

# %%
age_0 = 22
age_1 = 18

print(age_0 >= 21 and age_1 >= 21)  # False
print(age_0 >= 21 or age_1 >= 21)   # True

# %% [markdown]
# ## 7) `in` and `not in` / وجود داشتن یا نداشتن در لیست

# %%
requested_toppings = ['mushrooms', 'onions', 'pineapple']
print('mushrooms' in requested_toppings)   # True
print('pepperoni' in requested_toppings)   # False

# %%
banned_users = ['andrew', 'carolina', 'david']
user = 'marie'

if user not in banned_users:
    print(f"{user.title()}, you can post a response if you wish.")

# %% [markdown]
# ## 8) Boolean values / مقادیر بولی

# %%
game_active = True
can_edit = False
print(game_active, can_edit)

# %% [markdown]
# ## 9) Simple `if` / `if` ساده

# %%
age = 19
if age >= 18:
    print("You are old enough to vote!")
    print("Have you registered to vote yet?")

# %% [markdown]
# ## 10) `if-else` / شرط دوحالته

# %%
age = 17
if age >= 18:
    print("You are old enough to vote!")
    print("Have you registered to vote yet?")
else:
    print("Sorry, you are too young to vote.")
    print("Please register to vote as soon as you turn 18!")

# %% [markdown]
# ## 11) `if-elif-else` chain / زنجیره‌ی `if-elif-else`

# %%
age = 12

if age < 4:
    print("Your admission cost is $0.")
elif age < 18:
    print("Your admission cost is $25.")
else:
    print("Your admission cost is $40.")

# %% [markdown]
# ### Better style: set a value, then print once / سبک بهتر

# %%
age = 12

if age < 4:
    price = 0
elif age < 18:
    price = 25
else:
    price = 40

print(f"Your admission cost is ${price}.")

# %% [markdown]
# ## 12) Multiple `elif` blocks / چندین `elif`

# %%
age = 70

if age < 4:
    price = 0
elif age < 18:
    price = 25
elif age < 65:
    price = 40
else:
    price = 20

print(f"Your admission cost is ${price}.")

# %% [markdown]
# ## ⚖️ Difference Between if / elif / else
# ### تفاوت دقیق if، elif و else

# %% [markdown]
# ### if جداگانه
#
# ```python
# if x > 5:
#     print("Above 5")
#
# if x > 10:
#     print("Above 10")
# ```
#
# ✔️ هر دو ممکن است اجرا شوند

# %% [markdown]
# ### elif (زنجیره‌ای)
#
# ```python
# if x > 10:
#     print("Above 10")
# elif x > 5:
#     print("Above 5")
# ```
#
# ✔️ فقط اولین شرط True اجرا می‌شود

# %% [markdown]
# ### else
#
# ```python
# if x > 10:
#     print("Above 10")
# else:
#     print("10 or less")
# ```
#
# ✔️ وقتی هیچ شرطی True نباشد اجرا می‌شود

# %% [markdown]
# ## 13) Omitting `else` / حذف `else`

# %%
age = 70

if age < 4:
    price = 0
elif age < 18:
    price = 25
elif age < 65:
    price = 40
elif age >= 65:
    price = 20

print(f"Your admission cost is ${price}.")

# %% [markdown]
# ## 14) Testing multiple conditions / چند `if` مستقل

# %%
requested_toppings = ['mushrooms', 'extra cheese']

if 'mushrooms' in requested_toppings:
    print("Adding mushrooms.")
if 'pepperoni' in requested_toppings:
    print("Adding pepperoni.")
if 'extra cheese' in requested_toppings:
    print("Adding extra cheese.")

print("\nFinished making your pizza!")

# %% [markdown]
# ## 15) `if` with lists / `if` با لیست‌ها

# %% [markdown]
# ## 16) Checking for special items / آیتم خاص

# %%
requested_toppings = ['mushrooms', 'green peppers', 'extra cheese']

for requested_topping in requested_toppings:
    if requested_topping == 'green peppers':
        print("Sorry, we are out of green peppers right now.")
    else:
        print(f"Adding {requested_topping}.")

print("\nFinished making your pizza!")

# %% [markdown]
# ## 17) Checking that a list is not empty / خالی نبودن لیست

# %%
requested_toppings = []

if requested_toppings:
    for requested_topping in requested_toppings:
        print(f"Adding {requested_topping}.")
    print("\nFinished making your pizza!")
else:
    print("Are you sure you want a plain pizza?")

# %% [markdown]
# ## 18) Using multiple lists / دو لیست

# %%
available_toppings = ['mushrooms', 'olives', 'green peppers',
                      'pepperoni', 'pineapple', 'extra cheese']

requested_toppings = ['mushrooms', 'french fries', 'extra cheese']

for requested_topping in requested_toppings:
    if requested_topping in available_toppings:
        print(f"Adding {requested_topping}.")
    else:
        print(f"Sorry, we don't have {requested_topping}.")

print("\nFinished making your pizza!")

# %% [markdown]
# ## ❌ Common `if` Errors
# ### خطاهای رایج در if

# %% [markdown]
# ### ❌ Error 1: Forgetting colon (`:`)
#
# 🔴 SyntaxError

# %%
if age >= 18
    print("Adult")

# %% [markdown]
# ### ❌ Error 2: Wrong indentation
# 🔴 IndentationError

# %%
if age >= 18:
print("Adult")

# %% [markdown]
# ### ❌ Error 3: Using `=` instead of `==`
# 🔴 SyntaxError

# %%
if age = 18:
    print("Adult")

# %% [markdown]
# ### ❌ Error 4: Comparing incompatible types
# 🔴 TypeError

# %%
age = "18"
if age >= 18:
    print("Adult")

# %% [markdown]
# ### ❌ Error 5: else with condition
# 🔴 SyntaxError

# %%
else age < 18:
    print("Minor")

# %% [markdown]
# ## 5‑1) Conditional Tests

# %%
car = 'subaru'
print("Is car == 'subaru'? I predict True.")
print(car == 'subaru')

print("\nIs car == 'audi'? I predict False.")
print(car == 'audi')

age = 20
print("\nIs age >= 18? I predict True.")
print(age >= 18)

color = 'Red'
print("\nIs color.lower() == 'red'? I predict True.")
print(color.lower() == 'red')

# %% [markdown]
# ## 5‑2) More Conditional Tests

# %%
name = 'Alice'
print(name == 'Alice')
print(name != 'Bob')

num = 10
print(num > 5)
print(num <= 9)

items = ['apple', 'banana']
print('banana' in items)
print('cherry' not in items)

x, y = 5, 7
print(x < 10 and y < 10)
print(x == 5 or y == 5)

# %% [markdown]
# ## 5‑3) Stages of Life

# %%
age = 30

if age < 2:
    stage = "baby / نوزاد"
elif age < 4:
    stage = "toddler / نوپا"
elif age < 13:
    stage = "kid / کودک"
elif age < 20:
    stage = "teenager / نوجوان"
elif age < 65:
    stage = "adult / بزرگسال"
else:
    stage = "elder / سالمند"

print(stage)

# %% [markdown]
# ## 5‑4) Favorite Fruit

# %%
favorite_fruits = ['banana', 'apple', 'mango']

if 'banana' in favorite_fruits:
    print("You really like bananas!")
if 'apple' in favorite_fruits:
    print("You really like apples!")
if 'mango' in favorite_fruits:
    print("You really like mangoes!")
if 'orange' in favorite_fruits:
    print("You really like oranges!")
if 'strawberry' in favorite_fruits:
    print("You really like strawberries!")

# %% [markdown]
# ## 5‑5) Hello Admin

# %%
usernames = ['admin', 'jaden', 'sarah', 'mike', 'emma']

for username in usernames:
    if username == 'admin':
        print("Hello admin, would you like to see a status report?")
    else:
        print(f"Hello {username.title()}, thank you for logging in again.")

# %% [markdown]
# ## 5‑6) No Users

# %%
usernames = []

if usernames:
    for username in usernames:
        print(f"Hello {username.title()}!")
else:
    print("We need to find some users! / باید چند کاربر پیدا کنیم!")

# %% [markdown]
# ## 5‑7) Checking Usernames

# %%
current_users = ['Eric', 'Alice', 'Admin', 'John', 'Sarah']
new_users = ['john', 'mike', 'ALICE', 'zoe', 'Admin']

current_users_lower = [u.lower() for u in current_users]

for new_user in new_users:
    if new_user.lower() in current_users_lower:
        print(f"Sorry, '{new_user}' is taken. Please enter a new username.")
    else:
        print(f"Great, '{new_user}' is available!")
